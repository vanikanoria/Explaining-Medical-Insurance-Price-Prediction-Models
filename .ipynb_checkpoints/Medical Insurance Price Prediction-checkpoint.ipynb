# %% [markdown]
# # Explaining Medical Insurance Price Prediction Models
#
# In this project I apply 4 different machine learning models (Linear Regression, Random Forests, Decision Tree Regressor and XGBoost Regressor) to predict charges on medical insurance based on demographic characteristics of the holds of insurance. I then utilize feature importance functions in sklearn and SHAP analysis to attribute feature importance of each model.

# %%
#import libraries
import pandas as pd
import scipy
import sklearn
import numpy as np
import shap
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor, cv, DMatrix, plot_importance
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Medical_insurance.csv')

# %% [markdown]
# ### Source of dataset: https://www.kaggle.com/datasets/harishkumardatalab/medical-insurance-price-prediction

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Questions:
# 1. What are the most important factors that affect medical expenses?
# 2. How well can machine learning models predict medical expenses?
# 3. How do different models attribute feature importance, and does importance indicated by SHAP values differ from other feature iportance metrics.

# %% [markdown]
# ## First look at data

# %%
df.shape
# Out:
# (2772, 7)

# %%
#null values and duplicates
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.duplicated().sum()
# Out:
# 1435

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.corr(numeric_only=True) 
# age seems to be the most important feature - can try to infer from the model - SHAP values
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109344  0.041536  0.298308
# bmi       0.109344  1.000000  0.012755  0.198401
# children  0.041536  0.012755  1.000000  0.067389
# charges   0.298308  0.198401  0.067389  1.000000

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Get boolean variables for 'male' and 'smokes'

# %%
male = np.zeros(df.shape[0])

# %%
male[df['sex']=='male']=1

# %%
df['male']= male

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
#sex, smoker --> convert to boolean
#region --> dummy variables

#make functions
def smoker_convert(smoker):
    if smoker == 'yes':
        return 1
    else:
        return 0

# %%
df['smokes'] = df.loc[:,'smoker'].apply(smoker_convert)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  smokes
# 0      19  female  27.900         0    yes  southwest  16884.92400       1
# 1      18    male  33.770         1     no  southeast   1725.55230       0
# 2      28    male  33.000         3     no  southeast   4449.46200       0
# 3      33    male  22.705         0     no  northwest  21984.47061       0
# 4      32    male  28.880         0     no  northwest   3866.85520       0
# ...   ...     ...     ...       ...    ...        ...          ...     ...
# 1333   50    male  30.970         3     no  northwest  10600.54830       0
# 1334   18  female  31.920         0     no  northeast   2205.98080       0
# 1335   18  female  36.850         0     no  southeast   1629.83350       0
# 1336   21  female  25.800         0     no  southwest   2007.94500       0
# 1337   61  female  29.070         0    yes  northwest  29141.36030       1
#
# [1337 rows x 8 columns]

# %% [markdown]
# ## Get dummy variables for region

# %%
df['region'] = df['region'].astype('category')
df_new = pd.get_dummies(df, columns=['region'])

# %%
df_new
# Out:
#       age     sex     bmi  children smoker      charges  smokes  \
# 0      19  female  27.900         0    yes  16884.92400       1
# 1      18    male  33.770         1     no   1725.55230       0
# 2      28    male  33.000         3     no   4449.46200       0
# 3      33    male  22.705         0     no  21984.47061       0
# 4      32    male  28.880         0     no   3866.85520       0
# ...   ...     ...     ...       ...    ...          ...     ...
# 1333   50    male  30.970         3     no  10600.54830       0
# 1334   18  female  31.920         0     no   2205.98080       0
# 1335   18  female  36.850         0     no   1629.83350       0
# 1336   21  female  25.800         0     no   2007.94500       0
# 1337   61  female  29.070         0    yes  29141.36030       1
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# 1                False             False              True             False
# 2                False             False              True             False
# 3                False              True             False             False
# 4                False              True             False             False
# ...                ...               ...               ...               ...
# 1333             False              True             False             False
# 1334              True             False             False             False
# 1335             False             False              True             False
# 1336             False             False             False              True
# 1337             False              True             False             False
#
# [1337 rows x 11 columns]

# %%
df_clean = df_new.drop(['sex', 'smoker'], axis=1)

# %%
df_clean
# Out:
#       age     bmi  children      charges  smokes  region_northeast  \
# 0      19  27.900         0  16884.92400       1             False
# 1      18  33.770         1   1725.55230       0             False
# 2      28  33.000         3   4449.46200       0             False
# 3      33  22.705         0  21984.47061       0             False
# 4      32  28.880         0   3866.85520       0             False
# ...   ...     ...       ...          ...     ...               ...
# 1333   50  30.970         3  10600.54830       0             False
# 1334   18  31.920         0   2205.98080       0              True
# 1335   18  36.850         0   1629.83350       0             False
# 1336   21  25.800         0   2007.94500       0             False
# 1337   61  29.070         0  29141.36030       1             False
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# 2                False              True             False
# 3                 True             False             False
# 4                 True             False             False
# ...                ...               ...               ...
# 1333              True             False             False
# 1334             False             False             False
# 1335             False              True             False
# 1336             False             False              True
# 1337              True             False             False
#
# [1337 rows x 9 columns]

# %%
#convert region columns to integers
df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']] = df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']].astype(int)
# Out:
# /var/folders/71/v9k425r51tddm6v4ztbmjhy40000gn/T/ipykernel_87588/3458139230.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 0 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']] = df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']].astype(int)
# /var/folders/71/v9k425r51tddm6v4ztbmjhy40000gn/T/ipykernel_87588/3458139230.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 0 0 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']] = df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']].astype(int)
# /var/folders/71/v9k425r51tddm6v4ztbmjhy40000gn/T/ipykernel_87588/3458139230.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 1 1 ... 1 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']] = df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']].astype(int)
# /var/folders/71/v9k425r51tddm6v4ztbmjhy40000gn/T/ipykernel_87588/3458139230.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 0 ... 0 1 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']] = df_clean.loc[:,['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']].astype(int)

# %%
df_clean
# Out:
#       age     bmi  children      charges  smokes  region_northeast  \
# 0      19  27.900         0  16884.92400       1                 0
# 1      18  33.770         1   1725.55230       0                 0
# 2      28  33.000         3   4449.46200       0                 0
# 3      33  22.705         0  21984.47061       0                 0
# 4      32  28.880         0   3866.85520       0                 0
# ...   ...     ...       ...          ...     ...               ...
# 1333   50  30.970         3  10600.54830       0                 0
# 1334   18  31.920         0   2205.98080       0                 1
# 1335   18  36.850         0   1629.83350       0                 0
# 1336   21  25.800         0   2007.94500       0                 0
# 1337   61  29.070         0  29141.36030       1                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [1337 rows x 9 columns]

# %%
#look at correlation
df_clean.corr()
# Out:
#                        age       bmi  children   charges    smokes  \
# age               1.000000  0.109344  0.041536  0.298308 -0.025587
# bmi               0.109344  1.000000  0.012755  0.198401  0.003746
# children          0.041536  0.012755  1.000000  0.067389  0.007331
# charges           0.298308  0.198401  0.067389  1.000000  0.787234
# smokes           -0.025587  0.003746  0.007331  0.787234  1.000000
# region_northeast  0.001868 -0.138178 -0.023202  0.005945  0.002597
# region_northwest  0.001495 -0.136138  0.026044 -0.038695 -0.036321
# region_southeast -0.012311  0.270057 -0.023492  0.073578  0.068282
# region_southwest  0.009415 -0.006211  0.021538 -0.043637 -0.037168
#
#                   region_northeast  region_northwest  region_southeast  \
# age                       0.001868          0.001495         -0.012311
# bmi                      -0.138178         -0.136138          0.270057
# children                 -0.023202          0.026044         -0.023492
# charges                   0.005945         -0.038695          0.073578
# smokes                    0.002597         -0.036321          0.068282
# region_northeast          1.000000         -0.319842         -0.345909
# region_northwest         -0.319842          1.000000         -0.345909
# region_southeast         -0.345909         -0.345909          1.000000
# region_southwest         -0.320493         -0.320493         -0.346614
#
#                   region_southwest
# age                       0.009415
# bmi                      -0.006211
# children                  0.021538
# charges                  -0.043637
# smokes                   -0.037168
# region_northeast         -0.320493
# region_northwest         -0.320493
# region_southeast         -0.346614
# region_southwest          1.000000

# %%
#linear regression
#homoskedasticity --> normalize
#features are normally distributed

# %% [markdown]
# ## EDA:

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
rng = np.arange(df_clean['age'].min(), df_clean['age'].max(), 0.1)
norm.pdf(df_clean['age'].mean(), df_clean['age'].std())
# Out:
# 8.841196836550673e-139

# %%
plt.hist(df_clean['age'], density=True) #, bins=20)
rng = np.arange(df_clean['age'].min(), df_clean['age'].max(), 0.1)
plt.plot(rng, norm.pdf(rng, df_clean['age'].mean(), df_clean['age'].std()))
plt.title('Distribution of age variable', size=15)
plt.ylabel('prob dist. function')
plt.xlabel('Age (in years)')
plt.show()

# %% [markdown]
# * The age variable is roughly normally distributed

# %%
plt.hist(df_clean['bmi'], density=True) #, bins=20)
rng = np.arange(df_clean['bmi'].min(), df_clean['bmi'].max(), 0.1)
plt.plot(rng, norm.pdf(rng, df_clean['bmi'].mean(), df_clean['bmi'].std()))
plt.title('Distribution of BMI variable', size=15)
plt.ylabel('prob dist. function')
plt.xlabel('BMI')
plt.show()

# %% [markdown]
# * The age variable is roughly normally distributed

# %%
plt.scatter(df_clean['age'], df_clean['charges'], c= df_clean['smokes'], label=['smoker'])
plt.legend(labels = ['smoker'])
plt.title('Age versus medical charges with smokers highlighted', size=15)
plt.ylabel('Medical charges (in $)')
plt.xlabel('Age (in years)')
plt.show()

# %% [markdown]
# * On average, within the same age groups, smokers tend to have higher medical charges.

# %% [markdown]
# **Note**: Applying log to the charges column, something which is often done with monetary values, led to overfitting when the data was trained on all models since train accuracy increased, and test accuracy decreased for all models

# %% [markdown]
# ## Standardize and scale columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc =  StandardScaler()

# %%
#Create a copy with standardized numerical inputs
df_standardized =df_clean.copy()

# %%
pd.DataFrame(sc.fit_transform(df_clean.loc[:,['age','bmi','children','smokes', 'charges']]))
# Out:
#              0         1         2         3         4
# 0    -1.440418 -0.453160 -0.909234  1.969660  0.297857
# 1    -1.511647  0.509422 -0.079442 -0.507702 -0.954381
# 2    -0.799350  0.383155  1.580143 -0.507702 -0.729373
# 3    -0.443201 -1.305052 -0.909234 -0.507702  0.719104
# 4    -0.514431 -0.292456 -0.909234 -0.507702 -0.777499
# ...        ...       ...       ...       ...       ...
# 1332  0.767704  0.050269  1.580143 -0.507702 -0.221263
# 1333 -1.511647  0.206053 -0.909234 -0.507702 -0.914695
# 1334 -1.511647  1.014490 -0.909234 -0.507702 -0.962287
# 1335 -1.297958 -0.797524 -0.909234 -0.507702 -0.931054
# 1336  1.551231 -0.261299 -0.909234  1.969660  1.310298
#
# [1337 rows x 5 columns]

# %%
df_standardized[['age','bmi','children','smokes', 'charges']] = pd.DataFrame(sc.fit_transform(df_clean.loc[:,['age','bmi','children','smokes', 'charges']]))

# %%
df_standardized = df_standardized.dropna()
df_standardized
# Out:
#            age       bmi  children   charges    smokes  region_northeast  \
# 0    -1.440418 -0.453160 -0.909234  0.297857  1.969660                 0
# 1    -1.511647  0.509422 -0.079442 -0.954381 -0.507702                 0
# 2    -0.799350  0.383155  1.580143 -0.729373 -0.507702                 0
# 3    -0.443201 -1.305052 -0.909234  0.719104 -0.507702                 0
# 4    -0.514431 -0.292456 -0.909234 -0.777499 -0.507702                 0
# ...        ...       ...       ...       ...       ...               ...
# 1332  0.767704  0.050269  1.580143 -0.221263 -0.507702                 0
# 1333 -1.511647  0.206053 -0.909234 -0.914695 -0.507702                 0
# 1334 -1.511647  1.014490 -0.909234 -0.962287 -0.507702                 1
# 1335 -1.297958 -0.797524 -0.909234 -0.931054 -0.507702                 0
# 1336  1.551231 -0.261299 -0.909234  1.310298  1.969660                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1332                 0                 0                 1
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
#
# [1336 rows x 9 columns]

# %%
# get features and labels
y =  df_clean['charges']
x = df_clean.drop(['charges'], axis=1)

# %%
# get standardized features and labels
y_std =  df_standardized['charges']
x_std = df_standardized.drop(['charges'], axis=1)

# %%
# train, test split
train_x, test_x, train_y, test_y = train_test_split(x, y)
train_x_std, test_x_std, train_y_std, test_y_std = train_test_split(x_std, y_std)

# %% [markdown]
# # ML models for regression
# 1. Linear Regression
# 2. Decision Tree Regressors
# 3. Random Forest Regressors
# 4. XGBoost Regressors

# %% [markdown]
# ## Fit Linear Regression model with standardized numerical columns

# %%
lr = LinearRegression()

# %%
lr.fit(train_x_std, train_y_std)
# Out:
# LinearRegression()

# %%
train_pred_std = lr.predict(train_x_std)
test_pred_std = lr.predict(test_x_std)

# %%
r2_score(train_pred_std, train_y_std)
# Out:
# 0.6231446730998178

# %%
r2_score(test_pred_std, test_y_std)
# Out:
# 0.6957249552022866

# %%
mean_squared_error(train_pred_std, train_y_std)
# Out:
# 0.25927241421682673

# %%
mean_squared_error(test_pred_std, test_y_std)
# Out:
# 0.22579207252936515

# %% [markdown]
# ### Compute Feature importance using SHAP

# %%
explainer = shap.LinearExplainer(lr, train_x_std)
shap_values = explainer.shap_values(test_x_std)

# %%
shap.summary_plot(shap_values, test_x_std, feature_names=train_x_std.columns)

# %% [markdown]
# * The feature names are in order of importance from top to bottom on the Y-axis
# * The SHAP values on the X-axis represent the degree of change in log odds
# * Red indicates high valyes and blue indicates low values

# %% [markdown]
# ### Observations:
# * The model does not capture the variance and hence predictive power of smoking tendency, age, bmi and number of children i.e. all demographic features
# * The impact of the above variables on the model is close to 0 as shown in the plot above

# %%
shap.summary_plot(shap_values, test_x_std, plot_type="bar", feature_names = x.columns)

# %% [markdown]
# ## Inferences:
# #### This model relies on region as opposed to other features in encoding predictive power, which is not necessarily useful for this model

# %% [markdown]
# ## Retraining linear regression model without standardizing the features

# %%
lr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
train_pred = lr.predict(train_x)
test_pred = lr.predict(test_x)

# %%
r2_score(train_pred, train_y)
# Out:
# 0.6713549466994604

# %%
r2_score(test_pred, test_y)
# Out:
# 0.6441318583363469

# %%
mean_squared_error(train_pred, train_y)
# Out:
# 34899033.874973945

# %%
mean_squared_error(test_pred, test_y)
# Out:
# 41941030.96616249

# %% [markdown]
# ### Compute Feature importance using SHAP

# %%
explainer = shap.LinearExplainer(lr, train_x)
shap_values = explainer.shap_values(test_x)

# %%
shap.summary_plot(shap_values, test_x, feature_names=train_x.columns, show=False)
plt.title("SHAP summary plot of Linear Regression model predicting medical insurance prices ")
plt.show()

# %%
shap.summary_plot(shap_values, test_x, plot_type="bar", feature_names = x.columns)

# %% [markdown]
# ### This model is picking up predictive power of smokes, age and bmi, which make sense as importance features in determining medical insurance price prediction. This indicates that the Linear Regression model works much better without standardization of numerical columns.

# %% [markdown]
# ## Fit Random Forest Regressor
# Tree based models do not typically require standardization of features, which is why we do not use the standardized dataset

# %%
rf = RandomForestRegressor(n_estimators=1000)

# %%
rf.fit(train_x, train_y)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
train_pred_rf = rf.predict(train_x)
test_pred = rf.predict(test_x)

# %%
mean_squared_error(train_pred, train_y)
# Out:
# 34899095.576177

# %%
mean_squared_error(test_pred, test_y)
# Out:
# 22689205.544829365

# %%
r2_score(test_pred, test_y)
# Out:
# 0.8302480758275875

# %%
r2_score(train_pred_rf, train_y)
# Out:
# 0.9752781428066152

# %% [markdown]
# ### Compute feature importance
# 1. Using scikit-learn feature importance method

# %%
pd.DataFrame([train_x.columns, rf.feature_importances_])
# Out:
#           0         1         2         3                 4                 5  \
# 0       age       bmi  children    smokes  region_northeast  region_northwest
# 1  0.133374  0.200928   0.02184  0.625087            0.0058          0.005371
#
#                   6                 7
# 0  region_southeast  region_southwest
# 1          0.004186          0.003414

# %%
sorted_idx = rf.feature_importances_.argsort()
plt.barh(x.columns[sorted_idx], rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.show()

# %% [markdown]
# 2. Using SHAP

# %%
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(test_x)

# %%
shap.summary_plot(shap_values, test_x, plot_type="bar", feature_names = x.columns)

# %% [markdown]
# ## Inferences:
# #### This model relies primarily on demographic and personal indicators such as smokes, bmi and age to predict price
# * There is a slight discrepancy in order of importance of age and bmi as indicators between the feature importance function of sklearn and of the importance indicated by SHAP values.
#
# This may be because the feature importance function of sklearn depends on either the weight (number of times the feature is used to split the data across all trees), the cover (the number of times a features is used to split the data across all trees weighted by the number of training data points that go through those splits), or the gain (the average training loss reduction gained when using a feature for splitting) as explained the following article: https://towardsdatascience.com/interpretable-machine-learning-with-xgboost-9ec80d148d27

# %%
shap.summary_plot(shap_values, test_x, feature_names=x.columns, show=False)
plt.title("SHAP summary plot of Random Forests model predicting medical insurance prices ")
plt.show()

# %% [markdown]
# ### Observations:
#
# * Higher value of smoking leads to higher medical insurance prices, while lower values lead to lower prices
# * Age, BMI and number of children are also roughly directly proportional to medical insurance prices
# * People in the northeast and northwest seem to have higher insurance price predicted than other regions

# %% [markdown]
# ## Fit Decision Tree Regressor

# %%
dt = DecisionTreeRegressor()

# %%
train_y = train_y.astype(int)

# %%
dt.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
train_pred_dt = dt.predict(train_x)
test_pred = dt.predict(test_x)

# %%
mean_squared_error(test_pred, test_y)
# Out:
# 35379222.319376126

# %%
r2_score(test_pred, test_y)
# Out:
# 0.7563909535807907

# %%
r2_score(train_pred_dt, train_y)
# Out:
# 0.9994468966603374

# %%
mean_squared_error(train_pred_dt, train_y)
# Out:
# 77994.0139720559

# %% [markdown]
# ### Compute feature importance
# 1. Using scikit-learn feature importance method

# %%
sorted_idx = dt.feature_importances_.argsort()
plt.barh(x.columns[sorted_idx], dt.feature_importances_[sorted_idx])
plt.xlabel("Decision Trees Classifier Feature Importance")
plt.show()

# %% [markdown]
# ## Inferences:
# #### This model has similar feature importances as the Random Forests model, but lower R-squared score.

# %% [markdown]
# ## Fit XGBoost Regressor

# %%
xgb = XGBRegressor()

# %%
xgb.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
mean_squared_error(xgb.predict(train_x), train_y)
# Out:
# 539231.2465964106

# %%
mean_squared_error(xgb.predict(test_x), test_y)
# Out:
# 25656474.10723603

# %%
r2_score(xgb.predict(test_x), test_y)
# Out:
# 0.8180269568770451

# %%
r2_score(xgb.predict(train_x), train_y)
# Out:
# 0.9960737505355042

# %% [markdown]
# ### Compute feature importance
# 1. Using built-in feature importance method

# %%
feature_important = xgb.get_booster().get_score(importance_type='weight')
keys = list(x.columns)
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data2 = data.nlargest(40, columns="score").sort_values(by = "score", ascending=True)
plt.barh(data2.index, data2['score']) ## plot top 40 features
plt.title('Feature importance of XGBoost Regressor', size=20)
plt.show()

# %% [markdown]
# 2. Using SHAP

# %%
explainer = shap.Explainer(xgb)

# %%
shap_values = explainer(test_x)

# %%
shap.summary_plot(shap_values, test_x, plot_type="bar", feature_names = x.columns)

# %%
shap.summary_plot(shap_values, test_x, feature_names=x.columns, show=False)
plt.title("SHAP summary plot of XGBoost model predicting medical insurance prices")
plt.show()

# %% [markdown]
# ### Here, each point represents a prediction
#
# ### Observations:
#
# * Higher value of smoking leads to higher medical insurance prices, while lower values lead to lower prices
# * Age, bmi and number of children are also roughly directly proportional to medical insurance prices
# * People in the northeast and northwest seem to have higher insurance price predicted than other regions

# %% [markdown]
# # Conclusion
#
# * The **Random Forests** and **XGBoost** models have the highest test accuracy as measured by the R-squared metric, which is 81% for the XGBoost model, and 83% for the Random Forests model.
#
# * The most important feature in the models according to the SHAP analysis is the boolean feature **smokes**, which indicates that the models capture the trend that people who smoke will have higher price insurance charges.
